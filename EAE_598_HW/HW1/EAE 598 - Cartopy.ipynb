# %% [markdown]
# ### EAE 598 - Jupyter Notebook: Explaining Cartopy

# %% [markdown]
# #### As discussed in class, Cartopy is a library in Python that assists with geographic projections. It is developed on top of the popular data visualization library, Matplotlib, so they work nicely together.

# %% [markdown]
# The first step is to import Cartopy and Matplotlib

# %%
import cartopy.crs as ccrs 
import cartopy.feature as cfeature
import matplotlib.pyplot as plt

# %% [markdown]
# #### First Example: Basic Plotting
#
# #### Required Steps
#
# #### 1) Define your projection (e.g., PlateCarree)
# #### 2) Add cfeature for different features such as country and state borders as well as oceans, lakes, and rivers

# %%
# Add figure using matplotlib
fig = plt.figure()

# Add the PlateCarree projection to the matplotlib figure using cartopy
ax = fig.add_subplot(1, 1, 1, projection=ccrs.PlateCarree())

# Add the borders using cartopy
ax.add_feature(cfeature.BORDERS.with_scale('50m'), linewidth=0.5)

# Show the plot
plt.show()
# Out:
# /anaconda3/envs/pyEAE/lib/python3.9/site-packages/cartopy/io/__init__.py:241: DownloadWarning: Downloading: https://naturalearth.s3.amazonaws.com/50m_cultural/ne_50m_admin_0_boundary_lines_land.zip
#   warnings.warn(f'Downloading: {url}', DownloadWarning)

# %% [markdown]
# #### That plot looks a bit incomplete, particularly around the coastlines so let's add those!

# %%
# Add figure using matplotlib
fig = plt.figure()

# Add the PlateCarree projection to the matplotlib figure using cartopy
ax = fig.add_subplot(1, 1, 1, projection=ccrs.PlateCarree())

# Add the borders using cartopy
ax.add_feature(cfeature.BORDERS.with_scale('50m'), linewidth=0.5)

# Add the coastlines using cartopy
ax.add_feature(cfeature.COASTLINE.with_scale('50m'), linewidth=0.5)

# Show the plot
plt.show()
# Out:
# /anaconda3/envs/pyEAE/lib/python3.9/site-packages/cartopy/io/__init__.py:241: DownloadWarning: Downloading: https://naturalearth.s3.amazonaws.com/50m_physical/ne_50m_coastline.zip
#   warnings.warn(f'Downloading: {url}', DownloadWarning)

# %% [markdown]
# #### Much better, but let's focus on the United States

# %%
# Add figure using matplotlib
fig = plt.figure()

# Add the PlateCarree projection to the matplotlib figure using cartopy
ax = fig.add_subplot(1, 1, 1, projection=ccrs.PlateCarree())

# Add the borders using cartopy
ax.add_feature(cfeature.BORDERS.with_scale('50m'), linewidth=0.5)

# Add the coastlines using cartopy
ax.add_feature(cfeature.COASTLINE.with_scale('50m'), linewidth=0.5)

# Zoom into the United States using lat / lon coordinates with cartopy's set_extent() function
ax.set_extent([-125, -67, 24, 49])

# Show the plot
plt.show()

# %% [markdown]
# #### Good, but what about the states?

# %%
# Add figure using matplotlib
fig = plt.figure()

# Add the PlateCarree projection to the matplotlib figure using cartopy
ax = fig.add_subplot(1, 1, 1, projection=ccrs.PlateCarree())

# Add the borders using cartopy
ax.add_feature(cfeature.BORDERS.with_scale('50m'), linewidth=0.5)

# Add the coastlines using cartopy
ax.add_feature(cfeature.COASTLINE.with_scale('50m'), linewidth=0.5)

# Zoom into the United States using lat / lon coordinates with cartopy's set_extent() function
ax.set_extent([-125, -67, 24, 49])

# Add the state borders using cartopy
ax.add_feature(cfeature.STATES.with_scale('50m'), linewidth=0.5)

# Show the plot
plt.show()
# Out:
# /anaconda3/envs/pyEAE/lib/python3.9/site-packages/cartopy/io/__init__.py:241: DownloadWarning: Downloading: https://naturalearth.s3.amazonaws.com/50m_cultural/ne_50m_admin_1_states_provinces_lakes.zip
#   warnings.warn(f'Downloading: {url}', DownloadWarning)

# %% [markdown]
# #### Let's add some color to the land and water!

# %%
# Add figure using matplotlib
fig = plt.figure()

# Add the PlateCarree projection to the matplotlib figure using cartopy
ax = fig.add_subplot(1, 1, 1, projection=ccrs.PlateCarree())

# Add the borders using cartopy
ax.add_feature(cfeature.BORDERS.with_scale('50m'), linewidth=0.5)

# Add the coastlines using cartopy
ax.add_feature(cfeature.COASTLINE.with_scale('50m'), linewidth=0.5)

# Zoom into the United States using lat / lon coordinates with cartopy's set_extent() function
ax.set_extent([-125, -67, 24, 49])

# Add the state borders using cartopy
ax.add_feature(cfeature.STATES.with_scale('50m'), linewidth=0.5)

# Add the lakes using cartopy and shade them with a light blue color
ax.add_feature(cfeature.LAKES, zorder=1, color='#ecf9fd')

# Add the oceans using cartopy and shade them with a light blue color
ax.add_feature(cfeature.OCEAN, color='#ecf9fd')

# Add the land using cartopy and shade them with a beige color
ax.add_feature(cfeature.LAND, color='#fbf5e9')

# Show the plot
plt.show()
# Out:
# /anaconda3/envs/pyEAE/lib/python3.9/site-packages/cartopy/io/__init__.py:241: DownloadWarning: Downloading: https://naturalearth.s3.amazonaws.com/50m_physical/ne_50m_ocean.zip
#   warnings.warn(f'Downloading: {url}', DownloadWarning)
# /anaconda3/envs/pyEAE/lib/python3.9/site-packages/cartopy/io/__init__.py:241: DownloadWarning: Downloading: https://naturalearth.s3.amazonaws.com/50m_physical/ne_50m_land.zip
#   warnings.warn(f'Downloading: {url}', DownloadWarning)
# /anaconda3/envs/pyEAE/lib/python3.9/site-packages/cartopy/io/__init__.py:241: DownloadWarning: Downloading: https://naturalearth.s3.amazonaws.com/50m_physical/ne_50m_lakes.zip
#   warnings.warn(f'Downloading: {url}', DownloadWarning)

# %% [markdown]
# #### Now what about projections other than PlateCarree?

# %% [markdown]
# #### Example #2: Different Projections

# %% [markdown]
# #### AlbersEqualArea!

# %%
# Add figure using matplotlib
fig = plt.figure()

# Add the AlbersEqualArea projection to the matplotlib figure using cartopy
ax = fig.add_subplot(1, 1, 1, projection=ccrs.AlbersEqualArea())

# Add the borders using cartopy
ax.add_feature(cfeature.BORDERS.with_scale('50m'), linewidth=0.5)

# Add the coastlines using cartopy
ax.add_feature(cfeature.COASTLINE.with_scale('50m'), linewidth=0.5)

# Add the lakes using cartopy and shade them with a light blue color
ax.add_feature(cfeature.LAKES, zorder=1, color='#ecf9fd')

# Add the oceans using cartopy and shade them with a light blue color
ax.add_feature(cfeature.OCEAN, color='#ecf9fd')

# Add the land using cartopy and shade them with a beige color
ax.add_feature(cfeature.LAND, color='#fbf5e9')

# Show the plot
plt.show()
# Out:
# /anaconda3/envs/pyEAE/lib/python3.9/site-packages/cartopy/io/__init__.py:241: DownloadWarning: Downloading: https://naturalearth.s3.amazonaws.com/110m_physical/ne_110m_ocean.zip
#   warnings.warn(f'Downloading: {url}', DownloadWarning)
# /anaconda3/envs/pyEAE/lib/python3.9/site-packages/cartopy/io/__init__.py:241: DownloadWarning: Downloading: https://naturalearth.s3.amazonaws.com/110m_physical/ne_110m_land.zip
#   warnings.warn(f'Downloading: {url}', DownloadWarning)
# /anaconda3/envs/pyEAE/lib/python3.9/site-packages/cartopy/io/__init__.py:241: DownloadWarning: Downloading: https://naturalearth.s3.amazonaws.com/110m_physical/ne_110m_lakes.zip
#   warnings.warn(f'Downloading: {url}', DownloadWarning)

# %% [markdown]
# #### AzimuthalEquidistant!

# %%
# Add figure using matplotlib
fig = plt.figure()

# Add the AzimuthalEquidistant projection to the matplotlib figure using cartopy
ax = fig.add_subplot(1, 1, 1, projection=ccrs.AzimuthalEquidistant())

# Add the borders using cartopy
ax.add_feature(cfeature.BORDERS.with_scale('50m'), linewidth=0.5)

# Add the coastlines using cartopy
ax.add_feature(cfeature.COASTLINE.with_scale('50m'), linewidth=0.5)

# Add the lakes using cartopy and shade them with a light blue color
ax.add_feature(cfeature.LAKES, zorder=1, color='#ecf9fd')

# Add the oceans using cartopy and shade them with a light blue color
ax.add_feature(cfeature.OCEAN, color='#ecf9fd')

# Add the land using cartopy and shade them with a beige color
ax.add_feature(cfeature.LAND, color='#fbf5e9')

# Show the plot
plt.show()

# %% [markdown]
# #### LambertConformal!

# %%
# Add figure using matplotlib
fig = plt.figure()

# Add the LambertConformal projection to the matplotlib figure using cartopy
ax = fig.add_subplot(1, 1, 1, projection=ccrs.LambertConformal())

# Add the borders using cartopy
ax.add_feature(cfeature.BORDERS.with_scale('50m'), linewidth=0.5)

# Add the coastlines using cartopy
ax.add_feature(cfeature.COASTLINE.with_scale('50m'), linewidth=0.5)

# Add the lakes using cartopy and shade them with a light blue color
ax.add_feature(cfeature.LAKES, zorder=1, color='#ecf9fd')

# Add the oceans using cartopy and shade them with a light blue color
ax.add_feature(cfeature.OCEAN, color='#ecf9fd')

# Add the land using cartopy and shade them with a beige color
ax.add_feature(cfeature.LAND, color='#fbf5e9')

# Show the plot
plt.show()

# %% [markdown]
# #### LambertCylindrical!

# %%
# Add figure using matplotlib
fig = plt.figure()

# Add the LambertCylindrical projection to the matplotlib figure using cartopy
ax = fig.add_subplot(1, 1, 1, projection=ccrs.LambertCylindrical())

# Add the borders using cartopy
ax.add_feature(cfeature.BORDERS.with_scale('50m'), linewidth=0.5)

# Add the coastlines using cartopy
ax.add_feature(cfeature.COASTLINE.with_scale('50m'), linewidth=0.5)

# Add the lakes using cartopy and shade them with a light blue color
ax.add_feature(cfeature.LAKES, zorder=1, color='#ecf9fd')

# Add the oceans using cartopy and shade them with a light blue color
ax.add_feature(cfeature.OCEAN, color='#ecf9fd')

# Add the land using cartopy and shade them with a beige color
ax.add_feature(cfeature.LAND, color='#fbf5e9')

# Show the plot
plt.show()

# %% [markdown]
# #### Orthographic!

# %%
# Add figure using matplotlib
fig = plt.figure()

# Add the Orthographic projection to the matplotlib figure using cartopy
ax = fig.add_subplot(1, 1, 1, projection=ccrs.Orthographic())

# Add the borders using cartopy
ax.add_feature(cfeature.BORDERS.with_scale('50m'), linewidth=0.5)

# Add the coastlines using cartopy
ax.add_feature(cfeature.COASTLINE.with_scale('50m'), linewidth=0.5)

# Add the lakes using cartopy and shade them with a light blue color
ax.add_feature(cfeature.LAKES, zorder=1, color='#ecf9fd')

# Add the oceans using cartopy and shade them with a light blue color
ax.add_feature(cfeature.OCEAN, color='#ecf9fd')

# Add the land using cartopy and shade them with a beige color
ax.add_feature(cfeature.LAND, color='#fbf5e9')

# Show the plot
plt.show()

# %% [markdown]
# #### Sinusoidal!

# %%
# Add figure using matplotlib
fig = plt.figure()

# Add the Sinusoidal projection to the matplotlib figure using cartopy
ax = fig.add_subplot(1, 1, 1, projection=ccrs.Sinusoidal())

# Add the borders using cartopy
ax.add_feature(cfeature.BORDERS.with_scale('50m'), linewidth=0.5)

# Add the coastlines using cartopy
ax.add_feature(cfeature.COASTLINE.with_scale('50m'), linewidth=0.5)

# Add the lakes using cartopy and shade them with a light blue color
ax.add_feature(cfeature.LAKES, zorder=1, color='#ecf9fd')

# Add the oceans using cartopy and shade them with a light blue color
ax.add_feature(cfeature.OCEAN, color='#ecf9fd')

# Add the land using cartopy and shade them with a beige color
ax.add_feature(cfeature.LAND, color='#fbf5e9')

# Show the plot
plt.show()

# %% [markdown]
# #### Geostationary!

# %%
# Add figure using matplotlib
fig = plt.figure()

# Add the Geostationary projection to the matplotlib figure using cartopy
ax = fig.add_subplot(1, 1, 1, projection=ccrs.Geostationary())

# Add the borders using cartopy
ax.add_feature(cfeature.BORDERS.with_scale('50m'), linewidth=0.5)

# Add the coastlines using cartopy
ax.add_feature(cfeature.COASTLINE.with_scale('50m'), linewidth=0.5)

# Add the lakes using cartopy and shade them with a light blue color
ax.add_feature(cfeature.LAKES, zorder=1, color='#ecf9fd')

# Add the oceans using cartopy and shade them with a light blue color
ax.add_feature(cfeature.OCEAN, color='#ecf9fd')

# Add the land using cartopy and shade them with a beige color
ax.add_feature(cfeature.LAND, color='#fbf5e9')

# Show the plot
plt.show()

# %% [markdown]
# #### NorthPolarStereo!

# %%
# Add figure using matplotlib
fig = plt.figure()

# Add the NorthPolarStereo projection to the matplotlib figure using cartopy
ax = fig.add_subplot(1, 1, 1, projection=ccrs.NorthPolarStereo())

# Add the borders using cartopy
ax.add_feature(cfeature.BORDERS.with_scale('50m'), linewidth=0.5)

# Add the coastlines using cartopy
ax.add_feature(cfeature.COASTLINE.with_scale('50m'), linewidth=0.5)

# Add the lakes using cartopy and shade them with a light blue color
ax.add_feature(cfeature.LAKES, zorder=1, color='#ecf9fd')

# Add the oceans using cartopy and shade them with a light blue color
ax.add_feature(cfeature.OCEAN, color='#ecf9fd')

# Add the land using cartopy and shade them with a beige color
ax.add_feature(cfeature.LAND, color='#fbf5e9')

# Show the plot
plt.show()

# %% [markdown]
# #### SouthPolarStereo!

# %%
# Add figure using matplotlib
fig = plt.figure()

# Add the SouthPolarStereo projection to the matplotlib figure using cartopy
ax = fig.add_subplot(1, 1, 1, projection=ccrs.SouthPolarStereo())

# Add the borders using cartopy
ax.add_feature(cfeature.BORDERS.with_scale('50m'), linewidth=0.5)

# Add the coastlines using cartopy
ax.add_feature(cfeature.COASTLINE.with_scale('50m'), linewidth=0.5)

# Add the lakes using cartopy and shade them with a light blue color
ax.add_feature(cfeature.LAKES, zorder=1, color='#ecf9fd')

# Add the oceans using cartopy and shade them with a light blue color
ax.add_feature(cfeature.OCEAN, color='#ecf9fd')

# Add the land using cartopy and shade them with a beige color
ax.add_feature(cfeature.LAND, color='#fbf5e9')

# Show the plot
plt.show()

# %% [markdown]
# These projections are great in all but what about plotting with actual data?

# %% [markdown]
# #### Example 3: ERA5 Data with Cartopy

# %%
import xarray as xr
from siphon.catalog import TDSCatalog

# %% [markdown]
# #### Read in the ERA5 temperature data for 2/16/2021 using Xarray and select the temperature at 1000-hPa

# %%
# Define the ERA5 URL
era5_url = 'https://thredds.rda.ucar.edu/thredds/catalog/files/g/d633000/e5.oper.an.pl/202102/catalog.html?dataset=files/g/d633000/e5.oper.an.pl/202102/e5.oper.an.pl.128_130_t.ll025sc.2021021600_2021021623.nc'

# Use Siphon's TDSCatalog to download and open the ERA5 data in an Xarray Dataset
era5_ds = TDSCatalog(era5_url)
era5_ds = era5_ds.datasets[0].access_urls['OPENDAP']
ds = xr.open_dataset(era5_ds)

# Select the Temperature (T) at 1000-hPa in the Xarray Dataset and 
t_1000 = ds['T'].sel(level=1000) # units: K
# Out:
# /anaconda3/envs/pyEAE/lib/python3.9/site-packages/siphon/catalog.py:292: UserWarning: URL https://thredds.rda.ucar.edu/thredds/catalog/files/g/d633000/e5.oper.an.pl/202102/catalog.html?dataset=files/g/d633000/e5.oper.an.pl/202102/e5.oper.an.pl.128_130_t.ll025sc.2021021600_2021021623.nc returned HTML. Changing to: https://thredds.rda.ucar.edu/thredds/catalog/files/g/d633000/e5.oper.an.pl/202102/catalog.xml?dataset=files/g/d633000/e5.oper.an.pl/202102/e5.oper.an.pl.128_130_t.ll025sc.2021021600_2021021623.nc
#   warnings.warn('URL {} returned HTML. Changing to: {}'.format(self.catalog_url,

# %% [markdown]
# #### Iterate over the time dimension and plot the temperature at 1000-hPa with the PlateCarree projection

# %%
# For loop to iterate over the time dimension 
for i in range(0, 1):
    # Add figure using matplotlib
    fig = plt.figure()

    # Add the PlateCarree projection to the matplotlib figure using cartopy
    ax = fig.add_subplot(1, 1, 1, projection=ccrs.PlateCarree())
    
    # Add the borders using cartopy
    ax.add_feature(cfeature.BORDERS.with_scale('50m'), linewidth=0.5)

    # Add the coastlines using cartopy
    ax.add_feature(cfeature.COASTLINE.with_scale('50m'), linewidth=0.5)
    
    # Select the 0th time and plot it using Xarray's plot() function
    t_1000.isel(time=i).plot(ax=ax, transform=ccrs.PlateCarree(), cmap='coolwarm', cbar_kwargs={'label': 'Temperature (K)'})
    
    # Add a title
    plt.title('ERA5 Temperature Analysis')
    
    # Show the plot
    plt.show()

# %% [markdown]
# #### Okay, but let's focus on the United States

# %%
# For loop to iterate over the time dimension 
for i in range(0, 1):
    # Add figure using matplotlib
    fig = plt.figure()

    # Add the PlateCarree projection to the matplotlib figure using cartopy
    ax = fig.add_subplot(1, 1, 1, projection=ccrs.PlateCarree())
    
    # Add the borders using cartopy
    ax.add_feature(cfeature.BORDERS.with_scale('50m'), linewidth=0.5)

    # Add the coastlines using cartopy
    ax.add_feature(cfeature.COASTLINE.with_scale('50m'), linewidth=0.5)
    
    # Zoom into the United States using lat / lon coordinates with cartopy's set_extent() function
    ax.set_extent([-125, -67, 24, 49])

    # Select the 0th time and plot it using Xarray's plot() function
    t_1000.isel(time=i).plot(ax=ax, transform=ccrs.PlateCarree(), cmap='coolwarm', cbar_kwargs={'label': 'Temperature (K)'})
    
    # Add a title
    plt.title('ERA5 Temperature Analysis')
    
    # Show the plot
    plt.show()

# %% [markdown]
# #### The United States and Canada border is a bit distorted so let's try to fix

# %% [markdown]
# #### Iterate over the time dimension and plot the temperature at 1000-hPa with the LambertConformal projection

# %%
# For loop to iterate over the time dimension 
for i in range(0, 1):
    # Add figure using matplotlib
    fig = plt.figure()

    # Add the LambertConformal projection to the matplotlib figure using cartopy
    ax = fig.add_subplot(1, 1, 1, projection=ccrs.LambertConformal())
    
    # Add the borders using cartopy
    ax.add_feature(cfeature.BORDERS.with_scale('50m'), linewidth=0.5)

    # Add the coastlines using cartopy
    ax.add_feature(cfeature.COASTLINE.with_scale('50m'), linewidth=0.5)
    
    # Zoom into the United States using lat / lon coordinates with cartopy's set_extent() function
    ax.set_extent([-125, -67, 24, 49])

    # Select the 0th time and plot it using Xarray's plot() function
    t_1000.isel(time=i).plot(ax=ax, transform=ccrs.PlateCarree(), cmap='coolwarm', cbar_kwargs={'label': 'Temperature (K)'})
    
    # Add a title
    plt.title('ERA5 Temperature Analysis')
    
    # Show the plot
    plt.show()

# %% [markdown]
# #### Iterate over the time dimension and plot the temperature at 1000-hPa with the Orthographic projection

# %%
# For loop to iterate over the time dimension 
for i in range(0, 1):
    # Add figure using matplotlib
    fig = plt.figure()

    # Add the Orthographic projection to the matplotlib figure using cartopy
    ax = fig.add_subplot(1, 1, 1, projection=ccrs.Orthographic())
    
    # Add the borders using cartopy
    ax.add_feature(cfeature.BORDERS.with_scale('50m'), linewidth=0.5)

    # Add the coastlines using cartopy
    ax.add_feature(cfeature.COASTLINE.with_scale('50m'), linewidth=0.5)
    
    # Zoom into the United States using lat / lon coordinates with cartopy's set_extent() function
    ax.set_extent([-125, -67, 24, 49])

    # Select the 0th time and plot it using Xarray's plot() function
    t_1000.isel(time=i).plot(ax=ax, transform=ccrs.PlateCarree(), cmap='coolwarm', cbar_kwargs={'label': 'Temperature (K)'})
    
    # Add a title
    plt.title('ERA5 Temperature Analysis')
    
    # Show the plot
    plt.show()

# %% [markdown]
# #### Quite a rough projection... need to specify the central longitude and latitude to focus on North America

# %%
# For loop to iterate over the time dimension 
for i in range(0, 1):
    # Add figure using matplotlib
    fig = plt.figure()

    # Add the Orthographic projection to the matplotlib figure using cartopy but specify the central lat / lon coordinates
    ax = fig.add_subplot(1, 1, 1, projection=ccrs.Orthographic(central_longitude=-95, central_latitude=37.5))
    
    # Add the borders using cartopy
    ax.add_feature(cfeature.BORDERS.with_scale('50m'), linewidth=0.5)

    # Add the coastlines using cartopy
    ax.add_feature(cfeature.COASTLINE.with_scale('50m'), linewidth=0.5)
    
    # Zoom into the United States using lat / lon coordinates with cartopy's set_extent() function
    ax.set_extent([-125, -67, 24, 49])

    # Select the 0th time and plot it using Xarray's plot() function
    t_1000.isel(time=i).plot(ax=ax, transform=ccrs.PlateCarree(), cmap='coolwarm', cbar_kwargs={'label': 'Temperature (K)'})
    
    # Add a title
    plt.title('ERA5 Temperature Analysis')
    
    # Show the plot
    plt.show()
